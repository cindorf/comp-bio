# %% [markdown]
# <style>
# .analysis-title {
#     color: #2563eb !important;
#     font-size: 2.8rem;
#     font-weight: 700;
#     text-align: center;
#     border-bottom: 4px solid #dbeafe;
#     padding-bottom: 15px;
#     margin-bottom: 25px;
#     text-shadow: 2px 2px 4px rgba(0,0,0,0.1);
# }
# .metadata-box {
#     background: linear-gradient(135deg, #f8fafc 0%, #e2e8f0 100%);
#     border-left: 5px solid #3b82f6;
#     padding: 20px;
#     border-radius: 10px;
#     margin: 20px 0;
#     box-shadow: 0 4px 15px rgba(0,0,0,0.1);
# }
# .metadata-text {
#     color: #1e293b;
#     font-size: 1.1rem;
#     line-height: 1.8;
#     margin: 0;
# }
# .overview-header {
#     color: #1d4ed8 !important;
#     font-size: 2rem;
#     font-weight: 600;
#     border-left: 5px solid #3b82f6;
#     padding-left: 15px;
#     margin-top: 30px;
#     margin-bottom: 15px;
# }
# .section-text {
#     color: #374151;
#     font-size: 1.05rem;
#     line-height: 1.7;
#     text-align: justify;
# }
# .subsection-header {
#     color: #4338ca !important;
#     font-size: 1.4rem;
#     font-weight: 600;
#     margin-top: 25px;
#     margin-bottom: 10px;
#     border-bottom: 2px solid #e0e7ff;
#     padding-bottom: 5px;
# }
# .data-list {
#     background-color: #f8fafc;
#     border: 1px solid #e2e8f0;
#     border-radius: 8px;
#     padding: 15px;
#     margin: 15px 0;
# }
# .data-list ul {
#     margin: 0;
#     color: #475569;
#     font-size: 1rem;
# }
# .data-list li {
#     margin-bottom: 8px;
#     padding-left: 5px;
# }
# .data-list code {
#     background-color: #f1f5f9;
#     color: #dc2626;
#     padding: 2px 6px;
#     border-radius: 4px;
#     font-weight: 500;
# }
# </style>
#
# <h1 class="analysis-title">Damaging Mutation Sums</h1>
#
# <div class="metadata-box">
# <p class="metadata-text">
# <strong style="color: #1e40af;">Project:</strong> Computational Biology DMV Petri Dish<br>
# <strong style="color: #1e40af;">Author:</strong> Chris Indorf<br>
# <strong style="color: #1e40af;">Date:</strong> August 18, 2025<br>
# <strong style="color: #1e40af;">Language:</strong> Python
# </p>
# </div>
#
# <h2 class="overview-header">Overview</h2>
#
# <p class="section-text">This notebook performs data retrieval and visualization for analysis of cancer cell lines with damaging mutations. The notebook first connects to a PostgreSQL data warehouse to query mutation data, after which data analysis is performed. It then creates an interactive histogram visualization that provides filtering by tissue type, mutation value, and number of histogram bins.</p>
#
# <h3 class="subsection-header">Data Sources</h3>
# <div class="data-list">
# <ul>
# <li><strong>Database:</strong> data_warehouse (PostgreSQL)</li>
# <li><strong>Tables:</strong>
#     <ul>
#         <li><code>im_dep_sprime_damaging_mutations</code></li>
#         <li><code>im_dep_raw_secondary_dose_curve</code></li>
#         </ul>
# </li>
# </ul>
# </div>
#
# <h3 class="subsection-header">Libraries Used</h3>
# <div class="data-list">
# <ul>
# <li><code>psycopg2</code> - PostgreSQL database connectivity</li>
# <li><code>dotenv</code> - To retrieve environmental variable</li>
# <li><code>os</code> - To retrieve environmental variable</li>
# <li><code>pandas</code> - Data manipulation and analysis</li>
# <li><code>altair</code> - Statistical data visualization</li>
# <li><code>numpy</code> - Numerical functions</li>
# <li><code>warnings</code> - Suppresses warning messages</li>
# </ul>
# </div>
#
# <h3 class="subsection-header">Change Log</h3>
# <div class="data-list">
# <ul>
# <li><code>August 18, 2025 </code> - Version 1</li>
# </ul>
# </div>

# %%
# Import required libraries
import psycopg2
from dotenv import load_dotenv
import os
import pandas as pd
import altair as alt
import numpy as np
import warnings
# Ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <style>
# .section-header {
#     color: #1d4ed8 !important;
#     font-size: 2rem;
#     font-weight: 600;
#     border-left: 5px solid #3b82f6;
#     padding-left: 15px;
#     margin-top: 30px;
#     margin-bottom: 15px;
#     background: #f8fafc;
#     padding-top: 10px;
#     padding-bottom: 10px;
# }
# .description-text {
#     color: #374151;
#     font-size: 1.05rem;
#     line-height: 1.7;
#     margin-bottom: 20px;
# }
# .process-box {
#     background: #f8fafc;
#     border: 1px solid #e2e8f0;
#     border-radius: 10px;
#     padding: 20px;
#     margin: 20px 0;
# }
# .process-list {
#     color: #475569;
#     font-size: 1rem;
#     margin: 0;
# }
# .process-list li {
#     margin-bottom: 10px;
#     font-weight: 500;
# }
# .code-highlight {
#     background-color: #f8fafc;
#     color: #dc2626;
#     padding: 2px 6px;
#     border-radius: 4px;
#     font-family: 'Monaco', 'Consolas', monospace;
#     font-weight: 600;
# }
# </style>
#
# <h2 class="section-header">Data Retrieval</h2>
#
# <p class="description-text">Connects to the PostgreSQL database and executes queries to retrieve cancer cell lines with damaging mutations. The queries perform the following operations:</p>
#
# <div class="process-box">
# <ol class="process-list">
# <li><strong>Filters</strong> for different values of <span class="code-highlight">mutation_value </span> (damaging mutations)</li>
# <li><strong>Retrieves all cell lines or restricts</strong> cell lines to lung cancer cell lines (<span class="code-highlight">CCLE_name LIKE '%LUNG'</span>)</li>
# <li><strong>Groups</strong> by <span class="code-highlight">cell line</span> and sums mutation values for each cell line group</li>
# <li><strong>Orders</strong> results by cell line group</li>
# </ol>
# </div>

# %%
# Retrieve password from .env file  
load_dotenv()
password = os.getenv('DB_PASSWORD')  

# Establish database connection
conn = psycopg2.connect(
    host='dmvpetridishdatastore.dev',
    port=5432,
    database='data_warehouse',
    user='comp_bio_u2',
    password=password # password from .env
    # password='ENTER PASSWORD HERE' ### IN THIS DEVELOPMENT VERSION CAN REPLACE 'ENTER PASSWORD HERE' WITH ACTUAL PASSWORD
)
# Part 1. Sum damaging mutations in lung tissue cell lines.

# SQL query to sum damaging mutations in lung tissue cell lines
# Version 1. All mutations
query = """
SELECT cell_line, SUM(mutation_value) 
FROM public.im_dep_sprime_damaging_mutations
WHERE mutation_value > 0 
  AND cell_line IN (
    SELECT depmap_id 
    FROM public.im_dep_raw_secondary_dose_curve
    WHERE ccle_name LIKE '%LUNG')  
GROUP BY cell_line
ORDER BY cell_line;
"""
# Execute query and create DataFrame
df_lung_all = pd.read_sql_query(query, conn)

# SQL query to sum damaging mutations in lung tissue cell lines
# Version 2. Biallelic mutations
query = """
SELECT cell_line, SUM(mutation_value) 
FROM public.im_dep_sprime_damaging_mutations
WHERE mutation_value = 2 
  AND cell_line IN (
    SELECT depmap_id 
    FROM public.im_dep_raw_secondary_dose_curve
    WHERE ccle_name LIKE '%LUNG')  
GROUP BY cell_line
ORDER BY cell_line;
"""
# Execute query and create DataFrame
df_lung_2 = pd.read_sql_query(query, conn)

# SQL query to sum damaging mutations in lung tissue cell lines
# Version 3. Monoallelic mutations
query = """
SELECT cell_line, SUM(mutation_value) 
FROM public.im_dep_sprime_damaging_mutations
WHERE mutation_value = 1 
  AND cell_line IN (
    SELECT depmap_id 
    FROM public.im_dep_raw_secondary_dose_curve
    WHERE ccle_name LIKE '%LUNG')  
GROUP BY cell_line
ORDER BY cell_line;
"""
# Execute query and create DataFrame
df_lung_1 = pd.read_sql_query(query, conn)

# Part 2. Sum damaging mutations in cell lines for all tissues.

# SQL query to sum damaging mutations in cell lines for all tissues
# Version 1. All mutations
query = """
SELECT cell_line, SUM(mutation_value) 
FROM public.im_dep_sprime_damaging_mutations
WHERE mutation_value > 0 
GROUP BY cell_line
ORDER BY cell_line;
"""
# Execute query and create DataFrame
df_all = pd.read_sql_query(query, conn)

# SQL query to sum damaging mutations in cell lines for all tissues
# Version 2. Biallelic mutations
query = """
SELECT cell_line, SUM(mutation_value) 
FROM public.im_dep_sprime_damaging_mutations
WHERE mutation_value >= 2 
GROUP BY cell_line
ORDER BY cell_line;
"""
# Execute query and create DataFrame
df_all_2 = pd.read_sql_query(query, conn)

# SQL query to sum damaging mutations in cell lines for all tissues
# Version 3. Monoallelic mutations
query = """
SELECT cell_line, SUM(mutation_value) 
FROM public.im_dep_sprime_damaging_mutations
WHERE mutation_value= 1 
GROUP BY cell_line
ORDER BY cell_line;
"""
# Execute query and create DataFrame
df_all_1 = pd.read_sql_query(query, conn)

# SQL query to retrieve all values of tissue type to populate drop down.

query = """
    SELECT ccle_name FROM public.im_dep_raw_secondary_dose_curve;  
"""
# Execute query and create DataFrame
df_tissue_types = pd.read_sql_query(query, conn)

query = """
    SELECT DiSTINCT ccle_name FROM public.im_dep_raw_secondary_dose_curve;  
"""
# Execute query and create DataFrame
df_distinct_tissue_types = pd.read_sql_query(query, conn)
# Close database connection
conn.close()

# Display results
print("Lung tissue cell line damaging mutations - all mutations:")
print(df_lung_all)
print("Lung tissue cell line damaging mutations - biallelic mutations:")
print(df_lung_2)
print("Lung tissue cell line damaging mutations - monoallelic mutations:")
print(df_lung_1)
print("Cell line damaging mutations - all tissues - all mutations:")
print(df_all)
print("All tissues - cell line damaging mutations - biallelic mutations:")
print(df_all_2)
print("All tissues -  cell line damaging mutations - monoallelic mutations:")
print(df_all_1)
print("Tissue types:")
print(df_tissue_types)
print("Distinct tissue types:")
with pd.option_context('display.max_rows', None):
    tissue_list = df_distinct_tissue_types['ccle_name'].tolist()
    for i in range(0, len(tissue_list), 4):
        row = tissue_list[i:i+4]
        while len(row) < 4:
            row.append("")
        print(f"{str(row[0]):<45} {str(row[1]):<45} {str(row[2]):<45} {str(row[3]):45}")
# Out:
# Lung tissue cell line damaging mutations - all mutations:
#      cell_line  sum
# 0   ACH-000012   14
# 1   ACH-000015   58
# 2   ACH-000021   63
# 3   ACH-000030   32
# 4   ACH-000035   12
# ..         ...  ...
# 89  ACH-000924  206
# 90  ACH-000929  289
# 91  ACH-000945  345
# 92  ACH-001075   20
# 93  ACH-001113   58
#
# [94 rows x 2 columns]
# Lung tissue cell line damaging mutations - biallelic mutations:
#      cell_line  sum
# 0   ACH-000012    2
# 1   ACH-000015   12
# 2   ACH-000021   30
# 3   ACH-000030    4
# 4   ACH-000035    4
# ..         ...  ...
# 88  ACH-000921   94
# 89  ACH-000924   68
# 90  ACH-000929   88
# 91  ACH-000945   30
# 92  ACH-001113   16
#
# [93 rows x 2 columns]
# Lung tissue cell line damaging mutations - monoallelic mutations:
#      cell_line  sum
# 0   ACH-000012   12
# 1   ACH-000015   46
# 2   ACH-000021   33
# 3   ACH-000030   28
# 4   ACH-000035    8
# ..         ...  ...
# 89  ACH-000924  138
# 90  ACH-000929  201
# 91  ACH-000945  315
# 92  ACH-001075   20
# 93  ACH-001113   42
#
# [94 rows x 2 columns]
# Cell line damaging mutations - all tissues - all mutations:
#        cell_line  sum
# 0     ACH-000001   10
# 1     ACH-000002    5
# 2     ACH-000004   17
# 3     ACH-000005   20
# 4     ACH-000006   14
# ...          ...  ...
# 1783  ACH-003125   16
# 1784  ACH-003181   18
# 1785  ACH-003183   19
# 1786  ACH-003184   20
# 1787  ACH-003191   22
#
# [1788 rows x 2 columns]
# All tissues - cell line damaging mutations - biallelic mutations:
#        cell_line  sum
# 0     ACH-000001    2
# 1     ACH-000002    2
# 2     ACH-000004    6
# 3     ACH-000005    6
# 4     ACH-000006    4
# ...          ...  ...
# 1564  ACH-003120   14
# 1565  ACH-003121   20
# 1566  ACH-003125    2
# 1567  ACH-003183   10
# 1568  ACH-003184    4
#
# [1569 rows x 2 columns]
# All tissues -  cell line damaging mutations - monoallelic mutations:
#        cell_line  sum
# 0     ACH-000001    8
# 1     ACH-000002    3
# 2     ACH-000004   11
# 3     ACH-000005   14
# 4     ACH-000006   10
# ...          ...  ...
# 1783  ACH-003125   14
# 1784  ACH-003181   18
# 1785  ACH-003183    9
# 1786  ACH-003184   16
# 1787  ACH-003191   22
#
# [1788 rows x 2 columns]
# Tissue types:
#                                ccle_name
# 0                            JHOC5_OVARY
# 1                            JHOC5_OVARY
# 2                            JHOC5_OVARY
# 3                            JHOC5_OVARY
# 4                            JHOC5_OVARY
# ...                                  ...
# 1304980                      JHOC5_OVARY
# 1304981                      JHOC5_OVARY
# 1304982                      JHOC5_OVARY
# 1304983                      JHOC5_OVARY
# 1304984  CCFSTTG1_CENTRAL_NERVOUS_SYSTEM
#
# [1304985 rows x 1 columns]
# Distinct tissue types:
# 22RV1_PROSTATE                                2313287_STOMACH                               253JBV_URINARY_TRACT                          253J_URINARY_TRACT
# 42MGBA_CENTRAL_NERVOUS_SYSTEM                 5637_URINARY_TRACT                            639V_URINARY_TRACT                            647V_URINARY_TRACT
# 769P_KIDNEY                                   786O_KIDNEY                                   8305C_THYROID                                 8505C_THYROID
# 8MGBA_CENTRAL_NERVOUS_SYSTEM                  A101D_SKIN                                    A172_CENTRAL_NERVOUS_SYSTEM                   A204_SOFT_TISSUE
# A2058_SKIN                                    A2780_OVARY                                   A375_SKIN                                     A549_LUNG
# A673_BONE                                     A704_KIDNEY                                   ABC1_LUNG                                     ACCMESO1_PLEURA
# ACHN_KIDNEY                                   AGS_STOMACH                                   AN3CA_ENDOMETRIUM                             ASPC1_PANCREAS
# BC3C_URINARY_TRACT                            BCPAP_THYROID                                 BECKER_CENTRAL_NERVOUS_SYSTEM                 BEN_LUNG
# BFTC905_URINARY_TRACT                         BFTC909_KIDNEY                                BHT101_THYROID                                BICR16_UPPER_AERODIGESTIVE_TRACT
# BICR31_UPPER_AERODIGESTIVE_TRACT              BICR56_UPPER_AERODIGESTIVE_TRACT              BICR6_UPPER_AERODIGESTIVE_TRACT               BT474_BREAST
# BT549_BREAST                                  BXPC3_PANCREAS                                CADOES1_BONE                                  CAKI1_KIDNEY
# CAL120_BREAST                                 CAL12T_LUNG                                   CAL27_UPPER_AERODIGESTIVE_TRACT               CAL29_URINARY_TRACT
# CAL51_BREAST                                  CAL54_KIDNEY                                  CAL62_THYROID                                 CAL78_BONE
# CALU6_LUNG                                    CAMA1_BREAST                                  CAOV3_OVARY                                   CAPAN2_PANCREAS
# CCFSTTG1_CENTRAL_NERVOUS_SYSTEM               CFPAC1_PANCREAS                               CHL1_SKIN                                     CJM_SKIN
# CL34_LARGE_INTESTINE                          COLO668_LUNG                                  COLO679_SKIN                                  COLO680N_OESOPHAGUS
# COLO741_SKIN                                  COLO783_SKIN                                  COLO792_SKIN                                  COLO800_SKIN
# CORL105_LUNG                                  CORL23_LUNG                                   COV362_OVARY                                  COV434_OVARY
# DANG_PANCREAS                                 DAOY_CENTRAL_NERVOUS_SYSTEM                   DBTRG05MG_CENTRAL_NERVOUS_SYSTEM              DETROIT562_UPPER_AERODIGESTIVE_TRACT
# DKMG_CENTRAL_NERVOUS_SYSTEM                   DMS273_LUNG                                   DU145_PROSTATE                                EBC1_LUNG
# ECGI10_OESOPHAGUS                             EFM192A_BREAST                                EFO21_OVARY                                   EFO27_OVARY
# EN_ENDOMETRIUM                                ES2_OVARY                                     ESS1_ENDOMETRIUM                              EWS502_BONE
# FADU_UPPER_AERODIGESTIVE_TRACT                FTC133_THYROID                                FTC238_THYROID                                G292CLONEA141B1_BONE
# G361_SKIN                                     G401_SOFT_TISSUE                              G402_SOFT_TISSUE                              GAMG_CENTRAL_NERVOUS_SYSTEM
# GB1_CENTRAL_NERVOUS_SYSTEM                    GCIY_STOMACH                                  GCT_SOFT_TISSUE                               GI1_CENTRAL_NERVOUS_SYSTEM
# GMS10_CENTRAL_NERVOUS_SYSTEM                  GOS3_CENTRAL_NERVOUS_SYSTEM                   GP2D_LARGE_INTESTINE                          H4_CENTRAL_NERVOUS_SYSTEM
# HARA_LUNG                                     HCC1143_BREAST                                HCC1195_LUNG                                  HCC1359_LUNG
# HCC1419_BREAST                                HCC1428_BREAST                                HCC1438_LUNG                                  HCC15_LUNG
# HCC1806_BREAST                                HCC1937_BREAST                                HCC366_LUNG                                   HCC38_BREAST
# HCC4006_LUNG                                  HCC44_LUNG                                    HCC56_LARGE_INTESTINE                         HCC78_LUNG
# HCC827_LUNG                                   HCC95_LUNG                                    HCT116_LARGE_INTESTINE                        HCT15_LARGE_INTESTINE
# HDQP1_BREAST                                  HEC108_ENDOMETRIUM                            HEC151_ENDOMETRIUM                            HEC1A_ENDOMETRIUM
# HEC1B_ENDOMETRIUM                             HEC251_ENDOMETRIUM                            HEC265_ENDOMETRIUM                            HEC59_ENDOMETRIUM
# HEC6_ENDOMETRIUM                              HEP3B217_LIVER                                HEYA8_OVARY                                   HGC27_STOMACH
# HLF_LIVER                                     HMC18_BREAST                                  HOS_BONE                                      HPAC_PANCREAS
# HS294T_SKIN                                   HS729_SOFT_TISSUE                             HS766T_PANCREAS                               HS852T_SKIN
# HS939T_SKIN                                   HS944T_SKIN                                   HSC2_UPPER_AERODIGESTIVE_TRACT                HSC3_UPPER_AERODIGESTIVE_TRACT
# HT1080_SOFT_TISSUE                            HT1376_URINARY_TRACT                          HT144_SKIN                                    HT29_LARGE_INTESTINE
# HT55_LARGE_INTESTINE                          HUCCT1_BILIARY_TRACT                          HUH28_BILIARY_TRACT                           HUH6_LIVER
# HUH7_LIVER                                    HUPT3_PANCREAS                                IALM_LUNG                                     IGR1_SKIN
# IGR37_SKIN                                    IGROV1_OVARY                                  IM95_STOMACH                                  IPC298_SKIN
# ISHIKAWAHERAKLIO02ER_ENDOMETRIUM              ISTMES1_PLEURA                                ISTMES2_PLEURA                                J82_URINARY_TRACT
# JHH1_LIVER                                    JHH4_LIVER                                    JHH5_LIVER                                    JHH6_LIVER
# JHH7_LIVER                                    JHOC5_OVARY                                   JHOM1_OVARY                                   JHOS2_OVARY
# JHUEM2_ENDOMETRIUM                            JIMT1_BREAST                                  JMSU1_URINARY_TRACT                           K029AX_SKIN
# KALS1_CENTRAL_NERVOUS_SYSTEM                  KELLY_AUTONOMIC_GANGLIA                       KMBC2_URINARY_TRACT                           KMRC1_KIDNEY
# KMRC20_KIDNEY                                 KMRC3_KIDNEY                                  KNS42_CENTRAL_NERVOUS_SYSTEM                  KNS60_CENTRAL_NERVOUS_SYSTEM
# KNS62_LUNG                                    KNS81_CENTRAL_NERVOUS_SYSTEM                  KP2_PANCREAS                                  KP3_PANCREAS
# KP4_PANCREAS                                  KU1919_URINARY_TRACT                          KURAMOCHI_OVARY                               KYSE140_OESOPHAGUS
# KYSE150_OESOPHAGUS                            KYSE180_OESOPHAGUS                            KYSE270_OESOPHAGUS                            KYSE30_OESOPHAGUS
# KYSE410_OESOPHAGUS                            KYSE510_OESOPHAGUS                            KYSE520_OESOPHAGUS                            KYSE70_OESOPHAGUS
# L33_PANCREAS                                  LC1SQSF_LUNG                                  LCLC103H_LUNG                                 LI7_LIVER
# LK2_LUNG                                      LMSU_STOMACH                                  LN18_CENTRAL_NERVOUS_SYSTEM                   LN229_CENTRAL_NERVOUS_SYSTEM
# LNCAPCLONEFGC_PROSTATE                        LOUNH91_LUNG                                  LOVO_LARGE_INTESTINE                          LOXIMVI_SKIN
# LS1034_LARGE_INTESTINE                        LS180_LARGE_INTESTINE                         LS411N_LARGE_INTESTINE                        LS513_LARGE_INTESTINE
# LU99_LUNG                                     LUDLU1_LUNG                                   LXF289_LUNG                                   MALME3M_SKIN
# MCAS_OVARY                                    MCF7_BREAST                                   MDAMB175VII_BREAST                            MDAMB231_BREAST
# MDAMB435S_SKIN                                MDAMB436_BREAST                               MDAMB468_BREAST                               MELHO_SKIN
# MELJUSO_SKIN                                  MESSA_SOFT_TISSUE                             MEWO_SKIN                                     MFE280_ENDOMETRIUM
# MFE296_ENDOMETRIUM                            MFE319_ENDOMETRIUM                            MG63_BONE                                     MHHES1_BONE
# MIAPACA2_PANCREAS                             MKN1_STOMACH                                  MKN45_STOMACH                                 MKN74_STOMACH
# MKN7_STOMACH                                  MON_SOFT_TISSUE                               MPP89_PLEURA                                  MSTO211H_PLEURA
# NB1_AUTONOMIC_GANGLIA                         NCIH1048_LUNG                                 NCIH1299_LUNG                                 NCIH1339_LUNG
# NCIH1355_LUNG                                 NCIH1373_LUNG                                 NCIH1435_LUNG                                 NCIH1437_LUNG
# NCIH1563_LUNG                                 NCIH1568_LUNG                                 NCIH1573_LUNG                                 NCIH1581_LUNG
# NCIH1623_LUNG                                 NCIH1648_LUNG                                 NCIH1650_LUNG                                 NCIH1651_LUNG
# NCIH1693_LUNG                                 NCIH1703_LUNG                                 NCIH1792_LUNG                                 NCIH1793_LUNG
# NCIH1838_LUNG                                 NCIH1915_LUNG                                 NCIH1944_LUNG                                 NCIH1975_LUNG
# NCIH2009_LUNG                                 NCIH2023_LUNG                                 NCIH2030_LUNG                                 NCIH2052_PLEURA
# NCIH2087_LUNG                                 NCIH2110_LUNG                                 NCIH2122_LUNG                                 NCIH2126_LUNG
# NCIH2170_LUNG                                 NCIH2172_LUNG                                 NCIH2228_LUNG                                 NCIH226_LUNG
# NCIH2347_LUNG                                 NCIH23_LUNG                                   NCIH2444_LUNG                                 NCIH2452_PLEURA
# NCIH28_PLEURA                                 NCIH292_LUNG                                  NCIH322_LUNG                                  NCIH358_LUNG
# NCIH446_LUNG                                  NCIH460_LUNG                                  NCIH520_LUNG                                  NCIH522_LUNG
# NCIH596_LUNG                                  NCIH650_LUNG                                  NCIH661_LUNG                                  NCIH727_LUNG
# NCIH747_LARGE_INTESTINE                       NCIH838_LUNG                                  NCIH841_LUNG                                  NCIN87_STOMACH
# NUGC3_STOMACH                                 NUGC4_STOMACH                                 OAW42_OVARY                                   OC314_OVARY
# OC316_OVARY                                   OE19_OESOPHAGUS                               OE21_OESOPHAGUS                               OE33_OESOPHAGUS
# ONCODG1_OVARY                                 ONS76_CENTRAL_NERVOUS_SYSTEM                  OSRC2_KIDNEY                                  OUMS23_LARGE_INTESTINE
# OV56_OVARY                                    OV7_OVARY                                     OVCAR8_OVARY                                  OVISE_OVARY
# OVK18_OVARY                                   OVTOKO_OVARY                                  PANC0203_PANCREAS                             PANC0327_PANCREAS
# PANC0403_PANCREAS                             PANC0813_PANCREAS                             PANC1005_PANCREAS                             PANC1_PANCREAS
# PATU8902_PANCREAS                             PATU8988S_PANCREAS                            PATU8988T_PANCREAS                            PC14_LUNG
# PC3_PROSTATE                                  PECAPJ15_UPPER_AERODIGESTIVE_TRACT            PECAPJ41CLONED2_UPPER_AERODIGESTIVE_TRACT     PECAPJ49_UPPER_AERODIGESTIVE_TRACT
# PK1_PANCREAS                                  PK45H_PANCREAS                                PK59_PANCREAS                                 PLCPRF5_LIVER
# PSN1_PANCREAS                                 QGP1_PANCREAS                                 RCC10RGB_KIDNEY                               RCM1_LARGE_INTESTINE
# RD_SOFT_TISSUE                                RERFLCAD1_LUNG                                RERFLCAD2_LUNG                                RERFLCAI_LUNG
# RERFLCKJ_LUNG                                 RERFLCMS_LUNG                                 RH30_SOFT_TISSUE                              RKN_SOFT_TISSUE
# RKO_LARGE_INTESTINE                           RL952_ENDOMETRIUM                             RMGI_OVARY                                    RMUGS_OVARY
# RT112_URINARY_TRACT                           RT4_URINARY_TRACT                             RVH421_SKIN                                   S117_SOFT_TISSUE
# S117_THYROID                                  SBC5_LUNG                                     SCABER_URINARY_TRACT                          SCC25_UPPER_AERODIGESTIVE_TRACT
# SF126_CENTRAL_NERVOUS_SYSTEM                  SF295_CENTRAL_NERVOUS_SYSTEM                  SF539_CENTRAL_NERVOUS_SYSTEM                  SH10TC_STOMACH
# SH4_SKIN                                      SIMA_AUTONOMIC_GANGLIA                        SJSA1_BONE                                    SKES1_BONE
# SKHEP1_LIVER                                  SKLU1_LUNG                                    SKMEL24_SKIN                                  SKMEL2_SKIN
# SKMEL30_SKIN                                  SKMEL3_SKIN                                   SKMEL5_SKIN                                   SKMES1_LUNG
# SKNAS_AUTONOMIC_GANGLIA                       SKNBE2_AUTONOMIC_GANGLIA                      SKOV3_OVARY                                   SKUT1_SOFT_TISSUE
# SNB75_CENTRAL_NERVOUS_SYSTEM                  SNGM_ENDOMETRIUM                              SNU1041_UPPER_AERODIGESTIVE_TRACT             SNU1066_UPPER_AERODIGESTIVE_TRACT
# SNU1076_UPPER_AERODIGESTIVE_TRACT             SNU1077_ENDOMETRIUM                           SNU1079_BILIARY_TRACT                         SNU1105_CENTRAL_NERVOUS_SYSTEM
# SNU1196_BILIARY_TRACT                         SNU1214_UPPER_AERODIGESTIVE_TRACT             SNU213_PANCREAS                               SNU245_BILIARY_TRACT
# SNU308_BILIARY_TRACT                          SNU398_LIVER                                  SNU407_LARGE_INTESTINE                        SNU410_PANCREAS
# SNU423_LIVER                                  SNU449_LIVER                                  SNU466_CENTRAL_NERVOUS_SYSTEM                 SNU46_UPPER_AERODIGESTIVE_TRACT
# SNU601_STOMACH                                SNU61_LARGE_INTESTINE                         SNU668_STOMACH                                SNU685_ENDOMETRIUM
# SNU719_STOMACH                                SNU761_LIVER                                  SNU81_LARGE_INTESTINE                         SNU840_OVARY
# SNU869_BILIARY_TRACT                          SNU886_LIVER                                  SNUC2A_LARGE_INTESTINE                        SNUC4_LARGE_INTESTINE
# SNUC5_LARGE_INTESTINE                         SQ1_LUNG                                      SUIT2_PANCREAS                                SW1088_CENTRAL_NERVOUS_SYSTEM
# SW1271_LUNG                                   SW1353_BONE                                   SW1573_LUNG                                   SW1710_URINARY_TRACT
# SW1990_PANCREAS                               SW480_LARGE_INTESTINE                         SW48_LARGE_INTESTINE                          SW579_THYROID
# SW620_LARGE_INTESTINE                         SW780_URINARY_TRACT                           SW837_LARGE_INTESTINE                         SW900_LUNG
# SW948_LARGE_INTESTINE                         T24_URINARY_TRACT                             T3M10_LUNG                                    T47D_BREAST
# T98G_CENTRAL_NERVOUS_SYSTEM                   TCCPAN2_PANCREAS                              TCCSUP_URINARY_TRACT                          TE10_OESOPHAGUS
# TE11_OESOPHAGUS                               TE14_OESOPHAGUS                               TE1_OESOPHAGUS                                TE4_OESOPHAGUS
# TE5_OESOPHAGUS                                TE6_OESOPHAGUS                                TE8_OESOPHAGUS                                TE9_OESOPHAGUS
# TEN_ENDOMETRIUM                               TM31_CENTRAL_NERVOUS_SYSTEM                   TM87_SOFT_TISSUE                              TOV112D_OVARY
# TOV21G_OVARY                                  TT2609C02_THYROID                             TT_OESOPHAGUS                                 TT_THYROID
# TUHR4TKB_KIDNEY                               U118MG_CENTRAL_NERVOUS_SYSTEM                 U251MG_CENTRAL_NERVOUS_SYSTEM                 U2OS_BONE
# UACC257_SKIN                                  UACC62_SKIN                                   UBLC1_URINARY_TRACT                           UMUC1_URINARY_TRACT
# UO31_KIDNEY                                   VMCUB1_URINARY_TRACT                          VMRCRCW_KIDNEY                                VMRCRCZ_KIDNEY
# WM1799_SKIN                                   WM2664_SKIN                                   WM793_SKIN                                    WM88_SKIN
# WM983B_SKIN                                   YAPC_PANCREAS                                 YD10B_UPPER_AERODIGESTIVE_TRACT               YD15_SALIVARY_GLAND
# YD38_UPPER_AERODIGESTIVE_TRACT                YD8_UPPER_AERODIGESTIVE_TRACT                 YH13_CENTRAL_NERVOUS_SYSTEM                   YKG1_CENTRAL_NERVOUS_SYSTEM
# ZR751_BREAST                                  None

# %% [markdown]
# <style>
# .filtering-header {
#     color: #1d4ed8 !important;
#     font-size: 2rem;
#     font-weight: 600;
#     border-left: 5px solid #3b82f6;
#     padding-left: 15px;
#     margin-top: 30px;
#     margin-bottom: 15px;
#     background: #f8fafc;
#     padding-top: 10px;
#     padding-bottom: 10px;
# }
# .filtering-explanation {
#     background: #f8fafc;
#     border: 1px solid #e2e8f0;
#     border-radius: 10px;
#     padding: 20px;
#     margin: 20px 0;
#     color: #374151;
#     font-size: 1.05rem;
#     line-height: 1.7;
# }
# .highlight-number {
#     background-color: #f8fafc;
#     color: #475569;
#     padding: 3px 8px;
#     border-radius: 4px;
#     font-weight: 700;
#     font-size: 1.1rem;
# }
# </style>
#
# <h2 class="filtering-header">Data Analysis</h2>
#
# <div class="filtering-explanation">
# <p>Basic analysis and display of the cell line dataframes to support verification of the resulting histogram</p>
# </div>

# %%
# Analyze results of database retrieval Use pandas.
print ("Lung cell line damaging mutations - all mutations:")
print ('Number of cell lines:', df_lung_all.cell_line.count(), 
       'Smallest cell line number:', df_lung_all.cell_line.min(), 
       'Largest cell_line number:', df_lung_all.cell_line.max(), 
       'Total damaging mutations:', sum(df_lung_all['sum']))

# Show distribution of mutation counts across cell lines
# Left column: number of cell lines with damaging mutations
# Right column: number of cell lines with that count
print('\n')
print(df_lung_all['sum'].value_counts())

print ("Lung cell line damaging mutations - biallelic mutations:")
print ('Number of cell lines:', df_lung_2.cell_line.count(), 
       'Smallest cell line number:', df_lung_2.cell_line.min(), 
       'Largest cell_line number:', df_lung_2.cell_line.max(), 
       'Total damaging mutations:', sum(df_lung_2['sum']))

# Show distribution of mutation counts across cell lines
# Left column: number of cell lines with damaging mutations
# Right column: number of cell lines with that count
print('\n')
print(df_lung_2['sum'].value_counts())

print ("Lung cell line damaging mutations -monoallelic mutations:")
print ('Number of cell lines:', df_lung_1.cell_line.count(), 
       'Smallest cell line number:', df_lung_1.cell_line.min(), 
       'Largest cell_line number:', df_lung_1.cell_line.max(), 
       'Total damaging mutations:', sum(df_lung_1['sum']))
print('\n')
print(df_lung_1['sum'].value_counts())

print ("All tissues - cell line damaging mutations - all mutations:")
print ('Number of cell lines:', df_all.cell_line.count(), 
       'Smallest cell line number:', df_all.cell_line.min(), 
       'Largest cell_line number:', df_all.cell_line.max(), 
       'Total damaging mutations:', sum(df_all['sum']))

# Show distribution of mutation counts across cell lines
# Left column: number of cell lines with damaging mutations
# Right column: number of cell lines with that count
print('\n')
print(df_all['sum'].value_counts())

print ("All tissues - cell line damaging mutations - biallelic mutations:")
print ('Number of cell lines:', df_all_2.cell_line.count(), 
       'Smallest cell line number:', df_all_2.cell_line.min(), 
       'Largest cell_line number:', df_all_2.cell_line.max(), 
       'Total damaging mutations:', sum(df_all_2['sum']))

# Show distribution of mutation counts across cell lines
# Left column: number of cell lines with damaging mutations
# Right column: number of cell lines with that count
print('\n')
print(df_all_2['sum'].value_counts())

print ("All tissues - cell line damaging mutations -monoallelic mutations:")
print ('Number of cell lines:', df_all_1.cell_line.count(), 
       'Smallest cell line number:', df_all_1.cell_line.min(), 
       'Largest cell_line number:', df_all_1.cell_line.max(), 
       'Total damaging mutations:', sum(df_all_1['sum']))

# Show distribution of mutation counts across cell lines
# Left column: number of cell lines with damaging mutations
# Right column: number of cell lines with that count
print('\n')
print(df_all_1['sum'].value_counts())

# Print all values of tissue type
print('\n')
print('Tissue types value counts:')
with pd.option_context('display.max_rows', None):
    print(df_tissue_types['ccle_name'].value_counts())
print('\n')
# Out:
# Lung cell line damaging mutations - all mutations:
# Number of cell lines: 94 Smallest cell line number: ACH-000012 Largest cell_line number: ACH-001113 Total damaging mutations: 7939
#
#
# sum
# 51     4
# 45     3
# 63     3
# 65     3
# 66     3
#       ..
# 246    1
# 250    1
# 206    1
# 289    1
# 345    1
# Name: count, Length: 67, dtype: int64
# Lung cell line damaging mutations - biallelic mutations:
# Number of cell lines: 93 Smallest cell line number: ACH-000012 Largest cell_line number: ACH-001113 Total damaging mutations: 2334
#
#
# sum
# 12    8
# 4     8
# 16    8
# 18    7
# 24    7
# 28    6
# 8     6
# 10    4
# 14    4
# 30    4
# 2     3
# 68    3
# 32    2
# 20    2
# 22    2
# 46    2
# 38    2
# 50    2
# 76    1
# 6     1
# 52    1
# 40    1
# 42    1
# 44    1
# 26    1
# 58    1
# 78    1
# 48    1
# 74    1
# 94    1
# 88    1
# Name: count, dtype: int64
# Lung cell line damaging mutations -monoallelic mutations:
# Number of cell lines: 94 Smallest cell line number: ACH-000012 Largest cell_line number: ACH-001113 Total damaging mutations: 5605
#
#
# sum
# 29     4
# 46     3
# 23     3
# 28     3
# 32     3
#       ..
# 156    1
# 138    1
# 201    1
# 315    1
# 20     1
# Name: count, Length: 64, dtype: int64
# All tissues - cell line damaging mutations - all mutations:
# Number of cell lines: 1788 Smallest cell line number: ACH-000001 Largest cell_line number: ACH-003191 Total damaging mutations: 118364
#
#
# sum
# 21     61
# 18     59
# 22     52
# 24     49
# 16     47
#        ..
# 441     1
# 236     1
# 502     1
# 292     1
# 116     1
# Name: count, Length: 252, dtype: int64
# All tissues - cell line damaging mutations - biallelic mutations:
# Number of cell lines: 1569 Smallest cell line number: ACH-000001 Largest cell_line number: ACH-003184 Total damaging mutations: 18300
#
#
# sum
# 2      288
# 4      282
# 6      212
# 8      197
# 10     139
# 12      93
# 14      61
# 16      49
# 18      33
# 20      23
# 24      19
# 28      17
# 26      16
# 22      15
# 36      12
# 30       9
# 48       8
# 34       8
# 32       7
# 42       7
# 46       6
# 50       6
# 44       6
# 68       5
# 40       5
# 56       4
# 38       4
# 58       4
# 52       4
# 94       3
# 78       3
# 62       3
# 64       3
# 80       2
# 76       2
# 88       2
# 86       2
# 74       1
# 54       1
# 92       1
# 160      1
# 120      1
# 96       1
# 164      1
# 108      1
# 216      1
# 162      1
# Name: count, dtype: int64
# All tissues - cell line damaging mutations -monoallelic mutations:
# Number of cell lines: 1788 Smallest cell line number: ACH-000001 Largest cell_line number: ACH-003191 Total damaging mutations: 100064
#
#
# sum
# 16     67
# 14     66
# 15     58
# 11     57
# 12     57
#        ..
# 447     1
# 214     1
# 248     1
# 160     1
# 169     1
# Name: count, Length: 224, dtype: int64
#
#
# Tissue types value counts:
# ccle_name
# LCLC103H_LUNG                                2942
# DETROIT562_UPPER_AERODIGESTIVE_TRACT         2932
# ACHN_KIDNEY                                  2927
# WM1799_SKIN                                  2927
# SNU840_OVARY                                 2926
# NCIH1373_LUNG                                2926
# HCT116_LARGE_INTESTINE                       2926
# HCC366_LUNG                                  2926
# ONS76_CENTRAL_NERVOUS_SYSTEM                 2925
# KU1919_URINARY_TRACT                         2924
# SW1088_CENTRAL_NERVOUS_SYSTEM                2922
# HCC44_LUNG                                   2921
# IPC298_SKIN                                  2920
# 639V_URINARY_TRACT                           2919
# HDQP1_BREAST                                 2918
# JHOM1_OVARY                                  2918
# IM95_STOMACH                                 2918
# OC314_OVARY                                  2916
# SNU1041_UPPER_AERODIGESTIVE_TRACT            2916
# OVCAR8_OVARY                                 2915
# IGROV1_OVARY                                 2915
# T98G_CENTRAL_NERVOUS_SYSTEM                  2915
# MELJUSO_SKIN                                 2913
# CAL29_URINARY_TRACT                          2912
# SNU46_UPPER_AERODIGESTIVE_TRACT              2912
# HS294T_SKIN                                  2912
# NCIH2030_LUNG                                2911
# HCC827_LUNG                                  2911
# HSC3_UPPER_AERODIGESTIVE_TRACT               2910
# NUGC3_STOMACH                                2910
# UBLC1_URINARY_TRACT                          2909
# MCAS_OVARY                                   2906
# TE5_OESOPHAGUS                               2905
# ZR751_BREAST                                 2905
# KYSE510_OESOPHAGUS                           2905
# DU145_PROSTATE                               2903
# KNS42_CENTRAL_NERVOUS_SYSTEM                 2903
# JHH1_LIVER                                   2901
# COLO783_SKIN                                 2901
# GCT_SOFT_TISSUE                              2901
# NCIH226_LUNG                                 2899
# BICR31_UPPER_AERODIGESTIVE_TRACT             2899
# HCC15_LUNG                                   2896
# NCIH1437_LUNG                                2895
# TE10_OESOPHAGUS                              2895
# WM793_SKIN                                   2895
# 769P_KIDNEY                                  2895
# A2058_SKIN                                   2894
# NCIH1944_LUNG                                2892
# HCC78_LUNG                                   2891
# OE33_OESOPHAGUS                              2890
# HUH28_BILIARY_TRACT                          2889
# TOV21G_OVARY                                 2889
# NCIH1915_LUNG                                2888
# NCIH2452_PLEURA                              2887
# HCC1438_LUNG                                 2886
# MSTO211H_PLEURA                              2886
# 253JBV_URINARY_TRACT                         2886
# SNU668_STOMACH                               2885
# BEN_LUNG                                     2885
# NCIH292_LUNG                                 2884
# NCIH2009_LUNG                                2884
# PK1_PANCREAS                                 2883
# SKOV3_OVARY                                  2883
# PECAPJ49_UPPER_AERODIGESTIVE_TRACT           2883
# CHL1_SKIN                                    2882
# RMUGS_OVARY                                  2881
# CORL105_LUNG                                 2880
# HCT15_LARGE_INTESTINE                        2879
# HSC2_UPPER_AERODIGESTIVE_TRACT               2879
# TUHR4TKB_KIDNEY                              2878
# MDAMB468_BREAST                              2876
# NCIH2170_LUNG                                2875
# OVTOKO_OVARY                                 2874
# MDAMB435S_SKIN                               2874
# DBTRG05MG_CENTRAL_NERVOUS_SYSTEM             2874
# HCC1419_BREAST                               2873
# PATU8988T_PANCREAS                           2873
# HS939T_SKIN                                  2873
# SW1710_URINARY_TRACT                         2873
# MDAMB436_BREAST                              2873
# HEC251_ENDOMETRIUM                           2872
# A549_LUNG                                    2872
# RMGI_OVARY                                   2870
# RVH421_SKIN                                  2870
# ISTMES1_PLEURA                               2870
# NCIH2347_LUNG                                2868
# NCIH1651_LUNG                                2866
# CFPAC1_PANCREAS                              2865
# PK59_PANCREAS                                2864
# NCIH1339_LUNG                                2862
# MFE280_ENDOMETRIUM                           2862
# TOV112D_OVARY                                2860
# ECGI10_OESOPHAGUS                            2860
# KALS1_CENTRAL_NERVOUS_SYSTEM                 2858
# LN229_CENTRAL_NERVOUS_SYSTEM                 2858
# SNU1066_UPPER_AERODIGESTIVE_TRACT            2857
# WM983B_SKIN                                  2856
# HEC151_ENDOMETRIUM                           2855
# KYSE140_OESOPHAGUS                           2855
# HEC1B_ENDOMETRIUM                            2854
# NCIH1648_LUNG                                2854
# HUPT3_PANCREAS                               2853
# SNU719_STOMACH                               2852
# RCC10RGB_KIDNEY                              2851
# MFE319_ENDOMETRIUM                           2851
# ABC1_LUNG                                    2850
# NCIH2087_LUNG                                2849
# NCIH1563_LUNG                                2847
# SNU398_LIVER                                 2846
# HCC1143_BREAST                               2846
# NCIH460_LUNG                                 2845
# KYSE270_OESOPHAGUS                           2845
# GB1_CENTRAL_NERVOUS_SYSTEM                   2845
# TT_OESOPHAGUS                                2842
# ONCODG1_OVARY                                2842
# JHH5_LIVER                                   2842
# PATU8902_PANCREAS                            2842
# HCC4006_LUNG                                 2841
# HEC108_ENDOMETRIUM                           2840
# COLO800_SKIN                                 2840
# T47D_BREAST                                  2838
# HCC1428_BREAST                               2838
# SH10TC_STOMACH                               2838
# JHOS2_OVARY                                  2838
# CAKI1_KIDNEY                                 2837
# GP2D_LARGE_INTESTINE                         2835
# COLO680N_OESOPHAGUS                          2834
# SNU1196_BILIARY_TRACT                        2834
# HT29_LARGE_INTESTINE                         2834
# NB1_AUTONOMIC_GANGLIA                        2833
# U118MG_CENTRAL_NERVOUS_SYSTEM                2832
# SNU213_PANCREAS                              2832
# MKN1_STOMACH                                 2831
# NCIH1573_LUNG                                2830
# OUMS23_LARGE_INTESTINE                       2830
# NCIH1568_LUNG                                2829
# NCIH2228_LUNG                                2829
# NCIH1650_LUNG                                2829
# LMSU_STOMACH                                 2828
# SKMEL24_SKIN                                 2828
# JMSU1_URINARY_TRACT                          2828
# LS1034_LARGE_INTESTINE                       2826
# NCIH322_LUNG                                 2826
# SKMEL5_SKIN                                  2826
# MG63_BONE                                    2825
# NCIH747_LARGE_INTESTINE                      2824
# COLO741_SKIN                                 2823
# SKHEP1_LIVER                                 2822
# PK45H_PANCREAS                               2822
# DANG_PANCREAS                                2822
# YAPC_PANCREAS                                2822
# MESSA_SOFT_TISSUE                            2821
# HEC59_ENDOMETRIUM                            2820
# HEC6_ENDOMETRIUM                             2820
# CJM_SKIN                                     2819
# TT2609C02_THYROID                            2819
# MDAMB231_BREAST                              2818
# LXF289_LUNG                                  2817
# KMRC20_KIDNEY                                2816
# KYSE520_OESOPHAGUS                           2816
# JHUEM2_ENDOMETRIUM                           2815
# UACC257_SKIN                                 2815
# SNU869_BILIARY_TRACT                         2815
# SNU81_LARGE_INTESTINE                        2814
# YD38_UPPER_AERODIGESTIVE_TRACT               2811
# SNU308_BILIARY_TRACT                         2811
# HCC1806_BREAST                               2811
# LNCAPCLONEFGC_PROSTATE                       2810
# PECAPJ15_UPPER_AERODIGESTIVE_TRACT           2810
# WM88_SKIN                                    2809
# A101D_SKIN                                   2809
# NCIH2126_LUNG                                2809
# CAOV3_OVARY                                  2809
# LK2_LUNG                                     2808
# OE19_OESOPHAGUS                              2808
# KYSE30_OESOPHAGUS                            2807
# IALM_LUNG                                    2806
# 2313287_STOMACH                              2805
# 8305C_THYROID                                2805
# OVISE_OVARY                                  2805
# SNU423_LIVER                                 2805
# HEC1A_ENDOMETRIUM                            2804
# TCCSUP_URINARY_TRACT                         2803
# MCF7_BREAST                                  2803
# GOS3_CENTRAL_NERVOUS_SYSTEM                  2800
# OSRC2_KIDNEY                                 2800
# SKMEL2_SKIN                                  2799
# 786O_KIDNEY                                  2799
# MEWO_SKIN                                    2799
# UO31_KIDNEY                                  2799
# SNU1105_CENTRAL_NERVOUS_SYSTEM               2798
# RERFLCKJ_LUNG                                2798
# HPAC_PANCREAS                                2796
# HT55_LARGE_INTESTINE                         2796
# SW1573_LUNG                                  2795
# PANC0203_PANCREAS                            2794
# LC1SQSF_LUNG                                 2794
# MIAPACA2_PANCREAS                            2793
# BT549_BREAST                                 2793
# CAPAN2_PANCREAS                              2792
# TCCPAN2_PANCREAS                             2792
# VMRCRCZ_KIDNEY                               2792
# HCC1195_LUNG                                 2792
# NCIH1703_LUNG                                2790
# RT4_URINARY_TRACT                            2789
# BICR56_UPPER_AERODIGESTIVE_TRACT             2789
# HEP3B217_LIVER                               2789
# NCIH1355_LUNG                                2788
# G361_SKIN                                    2788
# NCIH358_LUNG                                 2788
# NCIH1975_LUNG                                2788
# SQ1_LUNG                                     2787
# BFTC905_URINARY_TRACT                        2787
# SNU1214_UPPER_AERODIGESTIVE_TRACT            2786
# QGP1_PANCREAS                                2786
# LOUNH91_LUNG                                 2782
# NCIH446_LUNG                                 2781
# 253J_URINARY_TRACT                           2780
# EFO27_OVARY                                  2780
# HUCCT1_BILIARY_TRACT                         2779
# NCIH1435_LUNG                                2779
# HT1376_URINARY_TRACT                         2779
# TE1_OESOPHAGUS                               2778
# KNS81_CENTRAL_NERVOUS_SYSTEM                 2776
# U2OS_BONE                                    2776
# 8MGBA_CENTRAL_NERVOUS_SYSTEM                 2775
# SNU685_ENDOMETRIUM                           2774
# DAOY_CENTRAL_NERVOUS_SYSTEM                  2774
# T24_URINARY_TRACT                            2773
# PANC0813_PANCREAS                            2771
# MHHES1_BONE                                  2771
# SNU449_LIVER                                 2770
# SKMEL30_SKIN                                 2770
# GMS10_CENTRAL_NERVOUS_SYSTEM                 2769
# CAL51_BREAST                                 2767
# TE9_OESOPHAGUS                               2766
# 8505C_THYROID                                2766
# NCIH1792_LUNG                                2765
# SNU886_LIVER                                 2765
# IGR1_SKIN                                    2764
# CAL27_UPPER_AERODIGESTIVE_TRACT              2763
# NCIH1048_LUNG                                2762
# SNB75_CENTRAL_NERVOUS_SYSTEM                 2762
# JHH7_LIVER                                   2761
# PC3_PROSTATE                                 2760
# BECKER_CENTRAL_NERVOUS_SYSTEM                2759
# SKES1_BONE                                   2759
# SKNBE2_AUTONOMIC_GANGLIA                     2758
# LUDLU1_LUNG                                  2757
# NCIH727_LUNG                                 2756
# MKN7_STOMACH                                 2756
# LN18_CENTRAL_NERVOUS_SYSTEM                  2756
# OE21_OESOPHAGUS                              2755
# RKN_SOFT_TISSUE                              2755
# LI7_LIVER                                    2755
# RCM1_LARGE_INTESTINE                         2755
# RT112_URINARY_TRACT                          2754
# SKUT1_SOFT_TISSUE                            2754
# EBC1_LUNG                                    2753
# SJSA1_BONE                                   2752
# JHOC5_OVARY                                  2750
# SNGM_ENDOMETRIUM                             2750
# HEC265_ENDOMETRIUM                           2749
# GCIY_STOMACH                                 2747
# NCIH1693_LUNG                                2746
# NCIH2444_LUNG                                2745
# SNUC2A_LARGE_INTESTINE                       2745
# KYSE70_OESOPHAGUS                            2745
# PLCPRF5_LIVER                                2744
# HCC38_BREAST                                 2743
# KNS62_LUNG                                   2742
# HOS_BONE                                     2741
# 647V_URINARY_TRACT                           2741
# COLO792_SKIN                                 2741
# SKMES1_LUNG                                  2739
# DKMG_CENTRAL_NERVOUS_SYSTEM                  2737
# TM87_SOFT_TISSUE                             2737
# HCC1359_LUNG                                 2737
# LU99_LUNG                                    2736
# FTC133_THYROID                               2735
# NCIH522_LUNG                                 2735
# SNU61_LARGE_INTESTINE                        2734
# NCIH23_LUNG                                  2733
# CAL54_KIDNEY                                 2733
# FADU_UPPER_AERODIGESTIVE_TRACT               2732
# HLF_LIVER                                    2728
# TE6_OESOPHAGUS                               2727
# SKLU1_LUNG                                   2724
# OC316_OVARY                                  2723
# BICR16_UPPER_AERODIGESTIVE_TRACT             2718
# NCIH520_LUNG                                 2718
# NCIH1838_LUNG                                2718
# KP2_PANCREAS                                 2717
# LOVO_LARGE_INTESTINE                         2717
# KNS60_CENTRAL_NERVOUS_SYSTEM                 2717
# NCIH2110_LUNG                                2716
# ASPC1_PANCREAS                               2714
# CAL120_BREAST                                2713
# SW1271_LUNG                                  2713
# HS729_SOFT_TISSUE                            2712
# BHT101_THYROID                               2711
# HCC1937_BREAST                               2711
# 5637_URINARY_TRACT                           2711
# TE11_OESOPHAGUS                              2710
# NCIH661_LUNG                                 2709
# WM2664_SKIN                                  2708
# SF539_CENTRAL_NERVOUS_SYSTEM                 2708
# PANC1_PANCREAS                               2707
# YH13_CENTRAL_NERVOUS_SYSTEM                  2707
# SW780_URINARY_TRACT                          2707
# KMBC2_URINARY_TRACT                          2706
# K029AX_SKIN                                  2706
# SNU466_CENTRAL_NERVOUS_SYSTEM                2705
# SCC25_UPPER_AERODIGESTIVE_TRACT              2705
# EFM192A_BREAST                               2702
# SNUC5_LARGE_INTESTINE                        2702
# SIMA_AUTONOMIC_GANGLIA                       2701
# IGR37_SKIN                                   2701
# HGC27_STOMACH                                2700
# NCIH841_LUNG                                 2700
# SW900_LUNG                                   2700
# LS180_LARGE_INTESTINE                        2700
# RH30_SOFT_TISSUE                             2700
# SW948_LARGE_INTESTINE                        2699
# A375_SKIN                                    2698
# 42MGBA_CENTRAL_NERVOUS_SYSTEM                2693
# SW480_LARGE_INTESTINE                        2691
# SNU1076_UPPER_AERODIGESTIVE_TRACT            2691
# G402_SOFT_TISSUE                             2689
# SW620_LARGE_INTESTINE                        2689
# SNU410_PANCREAS                              2688
# YD8_UPPER_AERODIGESTIVE_TRACT                2687
# HUH6_LIVER                                   2687
# COV362_OVARY                                 2685
# ESS1_ENDOMETRIUM                             2685
# HS766T_PANCREAS                              2684
# A172_CENTRAL_NERVOUS_SYSTEM                  2681
# EN_ENDOMETRIUM                               2681
# FTC238_THYROID                               2680
# PATU8988S_PANCREAS                           2680
# CORL23_LUNG                                  2676
# CAL62_THYROID                                2675
# KURAMOCHI_OVARY                              2673
# VMRCRCW_KIDNEY                               2673
# BT474_BREAST                                 2673
# RL952_ENDOMETRIUM                            2671
# NCIH2052_PLEURA                              2669
# MPP89_PLEURA                                 2669
# KYSE150_OESOPHAGUS                           2668
# KP3_PANCREAS                                 2668
# J82_URINARY_TRACT                            2667
# SW579_THYROID                                2663
# KMRC1_KIDNEY                                 2658
# SW837_LARGE_INTESTINE                        2657
# GAMG_CENTRAL_NERVOUS_SYSTEM                  2656
# CAMA1_BREAST                                 2654
# COLO679_SKIN                                 2654
# CAL78_BONE                                   2651
# RERFLCAD2_LUNG                               2650
# L33_PANCREAS                                 2649
# SF295_CENTRAL_NERVOUS_SYSTEM                 2648
# MKN74_STOMACH                                2646
# LOXIMVI_SKIN                                 2646
# SKNAS_AUTONOMIC_GANGLIA                      2644
# MDAMB175VII_BREAST                           2644
# LS513_LARGE_INTESTINE                        2643
# NCIH1793_LUNG                                2642
# SKMEL3_SKIN                                  2639
# AGS_STOMACH                                  2639
# CALU6_LUNG                                   2636
# SNUC4_LARGE_INTESTINE                        2634
# BFTC909_KIDNEY                               2633
# NCIH28_PLEURA                                2630
# UACC62_SKIN                                  2630
# COV434_OVARY                                 2629
# NCIH2023_LUNG                                2629
# TEN_ENDOMETRIUM                              2623
# TM31_CENTRAL_NERVOUS_SYSTEM                  2615
# PANC0327_PANCREAS                            2615
# H4_CENTRAL_NERVOUS_SYSTEM                    2613
# SNU1077_ENDOMETRIUM                          2611
# A204_SOFT_TISSUE                             2609
# CCFSTTG1_CENTRAL_NERVOUS_SYSTEM              2607
# EFO21_OVARY                                  2606
# MFE296_ENDOMETRIUM                           2605
# KYSE180_OESOPHAGUS                           2603
# BC3C_URINARY_TRACT                           2597
# PECAPJ41CLONED2_UPPER_AERODIGESTIVE_TRACT    2597
# A704_KIDNEY                                  2594
# SCABER_URINARY_TRACT                         2593
# RERFLCAD1_LUNG                               2593
# UMUC1_URINARY_TRACT                          2591
# A673_BONE                                    2591
# KYSE410_OESOPHAGUS                           2589
# BICR6_UPPER_AERODIGESTIVE_TRACT              2588
# CADOES1_BONE                                 2587
# CL34_LARGE_INTESTINE                         2587
# U251MG_CENTRAL_NERVOUS_SYSTEM                2585
# SW1990_PANCREAS                              2583
# T3M10_LUNG                                   2580
# RERFLCAI_LUNG                                2578
# HS944T_SKIN                                  2573
# EWS502_BONE                                  2565
# PANC1005_PANCREAS                            2561
# JHH6_LIVER                                   2561
# OAW42_OVARY                                  2559
# MALME3M_SKIN                                 2558
# HCC56_LARGE_INTESTINE                        2558
# TT_THYROID                                   2552
# SF126_CENTRAL_NERVOUS_SYSTEM                 2551
# NCIH1581_LUNG                                2549
# VMCUB1_URINARY_TRACT                         2547
# TE14_OESOPHAGUS                              2540
# SNU1079_BILIARY_TRACT                        2531
# RERFLCMS_LUNG                                2529
# SNU245_BILIARY_TRACT                         2528
# SW1353_BONE                                  2523
# YKG1_CENTRAL_NERVOUS_SYSTEM                  2521
# S117_SOFT_TISSUE                             2521
# KELLY_AUTONOMIC_GANGLIA                      2516
# ISTMES2_PLEURA                               2512
# NUGC4_STOMACH                                2510
# SNU761_LIVER                                 2506
# NCIH838_LUNG                                 2502
# HT1080_SOFT_TISSUE                           2501
# NCIN87_STOMACH                               2497
# LS411N_LARGE_INTESTINE                       2492
# BCPAP_THYROID                                2487
# NCIH1623_LUNG                                2486
# SW48_LARGE_INTESTINE                         2469
# PANC0403_PANCREAS                            2466
# OV56_OVARY                                   2461
# G292CLONEA141B1_BONE                         2459
# AN3CA_ENDOMETRIUM                            2455
# COLO668_LUNG                                 2451
# G401_SOFT_TISSUE                             2451
# HS852T_SKIN                                  2443
# 22RV1_PROSTATE                               2422
# GI1_CENTRAL_NERVOUS_SYSTEM                   2416
# HEYA8_OVARY                                  2415
# SH4_SKIN                                     2413
# HARA_LUNG                                    2397
# SBC5_LUNG                                    2350
# TE8_OESOPHAGUS                               2342
# ISHIKAWAHERAKLIO02ER_ENDOMETRIUM             2336
# HT144_SKIN                                   2321
# RKO_LARGE_INTESTINE                          2315
# BXPC3_PANCREAS                               2311
# MKN45_STOMACH                                2304
# YD10B_UPPER_AERODIGESTIVE_TRACT              2285
# ES2_OVARY                                    2261
# SUIT2_PANCREAS                               2243
# KMRC3_KIDNEY                                 2221
# MELHO_SKIN                                   2186
# DMS273_LUNG                                  2179
# TE4_OESOPHAGUS                               2116
# JIMT1_BREAST                                 2052
# PSN1_PANCREAS                                2052
# HUH7_LIVER                                   2018
# OV7_OVARY                                    2004
# KP4_PANCREAS                                 1980
# HCC95_LUNG                                   1966
# A2780_OVARY                                  1965
# JHH4_LIVER                                   1924
# PC14_LUNG                                    1907
# ACCMESO1_PLEURA                              1891
# RD_SOFT_TISSUE                               1841
# NCIH596_LUNG                                 1810
# SNU407_LARGE_INTESTINE                       1781
# NCIH1299_LUNG                                1763
# NCIH2172_LUNG                                1750
# MON_SOFT_TISSUE                              1747
# NCIH650_LUNG                                 1701
# YD15_SALIVARY_GLAND                          1701
# CAL12T_LUNG                                  1638
# OVK18_OVARY                                  1555
# HMC18_BREAST                                 1479
# SNU601_STOMACH                               1468
# NCIH2122_LUNG                                1356
# S117_THYROID                                  276
# Name: count, dtype: int64
# '\n# Sort dataframes ascending by sum\ndf_lung_all = df_lung_all.sort_values(\'sum\') \nprint(\'\n\')\nprint ("Lung cell line damaging mutations -sorted ascending by sum")\nprint(df_lung_all.head(50))\nprint(df_lung_all.tail(50))\n\ndf_all = df_all.sort_values(\'sum\') \nprint(\'\n\')\nprint ("Cell line damaging mutations -sorted ascending by sum")\nprint(df_all.head(50))\nprint(df_all.tail(50))\n'

# %% [markdown]
# <style>
# .viz-header {
#     color: #1d4ed8 !important;
#     font-size: 2rem;
#     font-weight: 600;
#     border-left: 5px solid #3b82f6;
#     padding-left: 15px;
#     margin-top: 30px;
#     margin-bottom: 15px;
#     background: #f8fafc;
#     padding-top: 10px;
#     padding-bottom: 10px;
# }
# .viz-description {
#     color: #374151;
#     font-size: 1.05rem;
#     line-height: 1.7;
#     margin-bottom: 20px;
# }
# .features-box {
#     background: #f8fafc;
#     border: 1px solid #e2e8f0;
#     border-radius: 10px;
#     padding: 20px;
#     margin: 20px 0;
# }
# .features-title {
#     color: #374151;
#     font-size: 1.3rem;
#     font-weight: 600;
#     margin-top: 0;
#     margin-bottom: 15px;
# }
# .features-list {
#     color: #475569;
#     font-size: 1rem;
#     margin: 0;
# }
# .features-list li {
#     margin-bottom: 12px;
#     font-weight: 500;
# }
# .feature-highlight {
#     background-color: #f8fafc;
#     color: #374151;
#     padding: 2px 6px;
#     border-radius: 4px;
#     font-weight: 600;
# }
# </style>
#
# <h2 class="viz-header">Data Preparation</h2>
#
# <p class="viz-description">Prepares dataframes for display in an interactive histogram that uses Altair to visualize a frequency distribution of the number of cell lines in bins of damaging mutation ranges.</p>
#
# <div class="features-box">
# <h3 class="features-title">Chart Features:</h3>
# <ul class="features-list">
# <li><span class="feature-highlight">Slider widget:</span> Dynamic slider allows the viewer to interactively select the number of cell line bins</li>
# <li><span class="feature-highlight">Tool tips:</span> Hovering mouse cursor over bin shows bin details</li>
# <li><span class="feature-highlight">Drop down menu:</span> Allows the viewer to select a cancer tissue type to display, or 'ALL' to display all tissues</li>
# <li><span class="feature-highlight">Radio buttons:</span> Allows the viewer to select the number of mutation values to display, or 'ALL' for all values</li>
# </ul>
# </div>

# %%
# Simple tissue dropdown - just ALL and LUNG

# Create tissue dropdown parameter
tissue_dropdown = alt.param(
    name='tissue_type',
    value='ALL',
    bind=alt.binding_select(
        options=['ALL', 'LUNG'],
        name='Tissue: '
    )
)

# Create mutation value filter (radio buttons)
mutation_filter = alt.param(
    name='mutation_category',
    value='all',
    bind=alt.binding_radio(
        options=['all', 'exactly_1', '2_or_more'],
        labels=['All mutations (≥1)', 'Exactly 1 mutation', '2 or more mutations'],
        name='Mutation Value: '
    )
)

df = df_all.copy()
cell_line = 'cell_line'
mutation_count = 'sum'   

# Configure slider parameters
bin_param = alt.param(
    name='num_bins',  # Same name as working version
    value=20, # Initial value
    bind=alt.binding_range(min=10, max=30, step=1, name='Number of Bins: ') # name = Slider label
)

# Prepare lung-specific data 
# Create combined dataset for LUNG tissues
df_lung_combined = df_lung_all.copy()
df_lung_combined['mutation_category'] = 'all'
df_lung_combined['tissue_filter'] = 'LUNG'

df_lung_2_labeled = df_lung_2.copy()
df_lung_2_labeled['mutation_category'] = '2_or_more'
df_lung_2_labeled['tissue_filter'] = 'LUNG'

df_lung_1_labeled = df_lung_1.copy()
df_lung_1_labeled['mutation_category'] = 'exactly_1'
df_lung_1_labeled['tissue_filter'] = 'LUNG'

# Add tissue_filter to existing ALL tissues data
all_tissues_data['tissue_filter'] = 'ALL'

# Combine lung data
lung_tissues_data = pd.concat([df_lung_combined, df_lung_2_labeled, df_lung_1_labeled], ignore_index=True)

# Combine ALL and LUNG datasets
all_and_lung_data = pd.concat([all_tissues_data, lung_tissues_data], ignore_index=True)

# Update binning loop to include tissue_filter
all_binned_data_simple = []

for mutation_cat in ['all', 'exactly_1', '2_or_more']:
    for tissue in ['ALL', 'LUNG']:
        # Filter data for this combination
        df_filtered = all_and_lung_data[
            (all_and_lung_data['mutation_category'] == mutation_cat) & 
            (all_and_lung_data['tissue_filter'] == tissue)
        ].copy()
        
        if df_filtered.empty:
            continue
            
        for n_bins in range(10, 31):
            df_temp = df_filtered.copy()
            df_temp['num_bins'] = n_bins
            
            # Create bins 
            bin_edges = np.linspace(df_filtered['sum'].min(), df_filtered['sum'].max(), n_bins + 1)
            df_temp['bin_assignment'] = pd.cut(df_temp['sum'], bins=bin_edges, include_lowest=True)
            
            binned = df_temp.groupby(['bin_assignment', 'num_bins', 'mutation_category', 'tissue_filter']).agg({
                'sum': 'sum',
                'cell_line': 'count'
            }).reset_index()
            
            binned.columns = ['bin_assignment', 'num_bins', 'mutation_category', 'tissue_filter', 'sum_value', 'count']
            
            # Calculate bin positions
            binned['bin_left'] = pd.to_numeric(binned['bin_assignment'].apply(lambda x: x.left))
            binned['bin_right'] = pd.to_numeric(binned['bin_assignment'].apply(lambda x: x.right))
            binned['bin_center'] = (binned['bin_left'] + binned['bin_right']) / 2
            
            binned = binned.drop('bin_assignment', axis=1)
            all_binned_data_simple.append(binned)

# Combine all data
combined_simple = pd.concat(all_binned_data_simple, ignore_index=True)
combined_simple = combined_simple[combined_simple['count'] > 0].reset_index(drop=True)

# %% [markdown]
# <style>
# .viz-header {
#     color: #1d4ed8 !important;
#     font-size: 2rem;
#     font-weight: 600;
#     border-left: 5px solid #3b82f6;
#     padding-left: 15px;
#     margin-top: 30px;
#     margin-bottom: 15px;
#     background: #f8fafc;
#     padding-top: 10px;
#     padding-bottom: 10px;
# }
# .viz-description {
#     color: #374151;
#     font-size: 1.05rem;
#     line-height: 1.7;
#     margin-bottom: 20px;
# }
# .features-box {
#     background: #f8fafc;
#     border: 1px solid #e2e8f0;
#     border-radius: 10px;
#     padding: 20px;
#     margin: 20px 0;
# }
# .features-title {
#     color: #374151;
#     font-size: 1.3rem;
#     font-weight: 600;
#     margin-top: 0;
#     margin-bottom: 15px;
# }
# .features-list {
#     color: #475569;
#     font-size: 1rem;
#     margin: 0;
# }
# .features-list li {
#     margin-bottom: 12px;
#     font-weight: 500;
# }
# .feature-highlight {
#     background-color: #f8fafc;
#     color: #374151;
#     padding: 2px 6px;
#     border-radius: 4px;
#     font-weight: 600;
# }
# </style>
#
# <h2 class="viz-header">Data Visualization</h2>
#
# <p class="viz-description">Creates and displays an interactive histogram that uses Altair to visualize a frequency distribution of the number of cell lines in bins of damaging mutation ranges..</p>
#
# <div class="features-box">
# <h3 class="features-title">Chart Features:</h3>
# <ul class="features-list">
# <li><span class="feature-highlight">Slider widget:</span> Dynamic slider allows the viewer to interactively select the number of cell line bins</li>
# <li><span class="feature-highlight">Tool tips:</span> Hovering mouse cursor over bin shows bin details</li>
# <li><span class="feature-highlight">Drop down menu:</span> Allows the viewer to select a cancer tissue type to display, or 'ALL' to display all tissues</li>
# <li><span class="feature-highlight">Radio buttons:</span> Allows the viewer to select the number of mutation values to display, or 'ALL' for all values</li>
# </ul>
# </div>

# %%
# Create chart
chart = alt.Chart(combined_simple).add_params(    
    tissue_dropdown,
    mutation_filter,
    bin_param  
).transform_filter(
    'datum.count > 0'
).transform_filter(
    'datum.tissue_filter == tissue_type'  
).transform_filter(
    'datum.mutation_category == mutation_category'
).transform_filter(
    'datum.num_bins == num_bins'
).mark_bar(
    color='steelblue',
    stroke='white',
    strokeWidth=0.1
).encode(
    alt.X('bin_center:Q',
          title='Damaging Mutation Sum'),
    alt.Y('count:Q',
          title='Number of Cell Lines',
          scale=alt.Scale(type='symlog'))
          # scale=alt.Scale(type='symlog', domain=[0.1, combined_simple['count'].max() * 1.1]))
).properties(
    width=600,
    height=400,
    title='Damaging Mutation Sums'
)

chart.show()
# Out:
# alt.Chart(...)

# %% [markdown]
# <style>
# .filtering-header {
#     color: #1d4ed8 !important;
#     font-size: 2rem;
#     font-weight: 600;
#     border-left: 5px solid #3b82f6;
#     padding-left: 15px;
#     margin-top: 30px;
#     margin-bottom: 15px;
#     background: #f8fafc;
#     padding-top: 10px;
#     padding-bottom: 10px;
# }
# .filtering-explanation {
#     background: #f8fafc;
#     border: 1px solid #e2e8f0;
#     border-radius: 10px;
#     padding: 20px;
#     margin: 20px 0;
#     color: #374151;
#     font-size: 1.05rem;
#     line-height: 1.7;
# }
# .highlight-number {
#     background-color: #f8fafc;
#     color: #475569;
#     padding: 3px 8px;
#     border-radius: 4px;
#     font-weight: 700;
#     font-size: 1.1rem;
# }
# </style>
#
# <h2 class="filtering-header">Chart storage</h2>
#
# <div class="filtering-explanation">
# <p>Save charts to files in HTML and PDF formats and create a link to a shareable URL.</p>
# </div>

# %%
# Save chart to HTML, PDF, and shareable URL. 
chart.save('Damaging Mutation Sums.html')
chart = chart.configure(background='white', padding=30).configure_view(fill='white')
chart.save('Damaging Mutation Sums.pdf')
chart.to_url() # Creates a shareable URL
# Out:
# 'https://vega.github.io/editor/#/url/vega--toIjgABABZUieYjQQEAZVIfmWbQ68gAjqRtERlB44GhVK5WlcsNJbjxSERlpQwNovi12p1KK0-AMkK4PlSggA5WGaTCGQEQGCAgDCY2kgIAMiRMJR4TTkaj0eCsTjXIwRAgxCgipIQLZDP4pcgANqgXwBeTESiUKYPBHTe6mbwkaxg+SUMaYMDibgQawQqD6g0gACCotFy1FAFU2QBxEAAXW4Js6ABU4BapshAXUQGhKVN5MHQxpjf5On4wZjoE8PJgEIM8VoSLdQI7nUFdQ4IMtvb7-SBKXJuJhzrpPq0HullskHoMHn5Bqp4yBpNoudJe4HZICywroJRAQAKQCmROkAJTLACiw490lagPSW-LvsnvJ5c8MmAfO79cYTJfkoK-QEADVc0wDMsxzSZOn7Opi1NIIyD8B47SlBt7VQEAW3ENs0QQaYGkuZwuBAPwSBQdJiMTeQOT8LkeT5QEACESEocDuBGTBrHI1xILzZBUjURcWR+P4AVOEFHzgSEYT8VCQFWNFKBgQY4UNUAZFeeR3EIWEdkgElCEBAA+QE2FgkANO5LSPF081LUwB5LJ5ABeZzATsq0bXMpzrJ0vwdm3CsoCrFRa0MW9XM-...-3gollAQ52MPq-RzGitKGOwab-GkuKyIdlBlGB8HlGKeypOafur807N5mB0t7OvsSvOuftnnHeQeI2+SN3Idhx5a+QSI252Du4cD7DYlyEnw6SrJSh2MmR71seDbpqTjerRnzczufPpt5eZgdlBFAyRYhlwhqwT23siaXwKDLFuNMWB30iNfQmZMY5sHjpTa6+oX6pxNp-GerN55-z+ivQua9K7sG3sAyBO9EGazgXLcildkixxQUMdI6R1Z7EwaPG6uDJ74PThbDyOdF5DHzmQouyQCjpA7uXbCW8m77y4VwthTcz5OwFn3dhzCUbjV4U-fhKdBEf2Ed-URC8fr-0tKvIBt0ih5GobdWhWixpCw0fA9IBRBb310Q4lIDdDGJ2MRPaKQjp4Z1npYkhdsAF2L4grFgSiFE0OUV7SGPjYh+M8Uw268Rkk7F3sbVWHDIhFDGhUx+IScFV1fo9MxkSRFWysUvUh8TyH2IKKUVIHjUm3VyI3OG+9kao1yUHbx2SWDlP8RvTWoDgnYL5mE+mESmZRKIb-XOEibGAL4hRGGKTwHIEVq426vjpknwDvA0uY0Uhi07qU4BLAlZsAqYs-WdS8GNPWc04h2z8ztNsZ0vipQihR2cckK5NcMmsG8bHZIDzT7wMVug0oVc4Zd0JognGmpSjVKWbdL5pjnpNIsS02JBci7ePBUckW-FShnNRUU9FjCg6RHYMfHx-ifHpFjgUglnyVlvynr88l-zxGAricCoukRK7EX6Yy9JUCOW7HeWy7C8RiagI8Zip5682B33SNMqoHAzUcH2DrLBQrDYktNmK6JFKAWcyBXsoGsQ2DIOJO7XVe9YXr21fzDVKAwVjX5kovVEcUAX17h85+xLwk-K-o6iV1jXUJMCKXRBzihl+qgaGvYsQI3XLyZwtgrDiiwMeVGmmJc+4crjfwhNqyk2EKzlsyVLrpVuuYSDZxGK82QwohWipwbi7dPvoa-xnDQHjURYK+NwqGmkodZs9mzrJEdOpYir1-SB0wqgVwidpQp3jMhkUTI40CnTujtk7plqE6Es4Uu9+K7k1rrEWm7tGbyKOL6cc-d8N-VyMvYi3NwVNHnOxpraZ06ihk3vsUeDQ8UaxAXU2l9or33tvXZ2zdMq15JLpRXM53joMcq9ci0tBTWHFKePqqGBQY6lzQ1avhOClH1Nffa7DP9cNfqpWvAocdEX9q1sWg9SN75jKoxMipBjZkxy4VUtjRiOOYbWbxmJG7dk-ppsJqt-SXakfkzIsdIC75VsjUlSuSsXmNvU7axNb6218c--9rdFDZHyP86R7xY06OQa4fowb1n4cBaVkez7XDvs8bO6mjzgn7FyKcd6yGJmo4PZLRMwWStIcU44bIsaH3DtPs498n74q-vM4B-YojkLSP85e1DmjsOhfkS1nfBIyPjX04IRj87WOCNdLyINvd5SkWDpQKMpVj2nZS2KP46GJMfN68bidlLv3+Ny+x-Y0ouvnHGeVR1p30Lm55PVnZtgq36M1tSLsApD7rXP091LhnRumfzZZ3xbGFv-Odf3tHhusex2ajVXK-x0cY6xAFrT9PdrDc+-S1K3PgQuEw2BxXa3a2TkcGPlXrbTGY6RG8f4xxryQYe4N+YlNsuc-y9BbEHp-be9dbrhFsfUWIPwNyL3Hz9vov6uKrsdIPSG+z7JfP33i--d8SKCA-99LKM24PpfQ-fX9E9M6+V9eEWFZIhL9Udl1M8W85s28l93VPVnE4994N474f8x0250Esh-F7sZ8QDuNm8Zdb9ID79AhUhuUOc0lhl-UUCik0CodPVe4S5AM--dTd9kOBRNwjhNSMyjylOtIMoVskQF3D48kp+Ze5HEVNpDn40izC58P1gjmtZV0Vu9FEi9-VejxoL4x0Xk+Uekj8PCkpS4z82BsYUMB4gC-CJi6jGcF98CmiO9wcFZIVlioFNj75kgdjI8g54MxphN6D9Uo4Y4Dtxj+FJim9pigisiCDmFPVG5+kAsmUENvix0x875K4I8-8fE7Mek9dgS5DzCZjwSbjRYwF6V1994kTxo5E+tH8+52jKiD5Z02BnYsSLis8rirCISD4ltYCzl89qT19IMMD0C3lNYtUmSsD6sWS8C2SCTboPV8j8d1Dtsedd88kUYz8KjNdkAekplK5RT0jcSwSdNLtCNjUlV+lHjsJVS9h1Tech1jVY51jaSKJZF75yldSpjr88TDSFsccKTwjQdgMS4lZH83iSc4tKCfjPDXjkS3SQSPSDSLtvTWc-1eCFTjUx9wzYiihQZY5fSNS5EAs+5MTaixT0dwD8TlCwiYTSNiopkaSHd8l4jp1oYz8RTacq09TQTZtyy9MmMOVoSAM5VAMRlpMQyvEoZj4eV3sUY9d2z3TAiuyvSuCEFD5nFoYCcRjzNS4dFHToMKJzV9yWi2zmSyzFzsii1NRIU3ji8ty49IMFYlZAs-8QsZzjyFDZij ...

# %% [markdown]
# <style>
# .results-header {
#     color: #2563eb !important;
#     font-size: 2.2rem;
#     font-weight: 700;
#     text-align: center;
#     border: 3px solid #dbeafe;
#     background: #f8fafc;
#     padding: 20px;
#     border-radius: 15px;
#     margin: 30px 0 25px 0;
#     text-shadow: 1px 1px 3px rgba(0,0,0,0.1);
# }
# .summary-intro {
#     background: #f8fafc;
#     color: black;
#     padding: 25px;
#     border-radius: 12px;
#     margin: 25px 0;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.15);
# }
# .summary-text {
#     font-size: 1.1rem;
#     line-height: 1.7;
#     margin: 0;
# }
# .highlight-stat {
#     background-color: #f8fafc;
#     color: #4338ca;
#     padding: 4px 10px;
#     border-radius: 6px;
#     font-weight: 700;
#     font-size: 1.15rem;
# }
# .key-findings {
#     background-color: #f8fafc;
#     border: 2px solid #dbeafe;
#     border-radius: 10px;
#     padding: 20px;
#     margin: 20px 0;
# }
# .findings-title {
#     color: #4338ca !important;
#     font-size: 1.4rem;
#     font-weight: 600;
#     margin-top: 0;
#     margin-bottom: 15px;
#     border-bottom: 2px solid #dbeafe;
#     padding-bottom: 8px;
# }
# .findings-list {
#     color: #1e3a8a;
#     font-size: 1rem;
#     margin: 0;
# }
# .findings-list li {
#     margin-bottom: 10px;
#     padding-left: 8px;
#     border-left: 3px solid #60a5fa;
#     padding-top: 5px;
#     padding-bottom: 5px;
#     background-color: #f8fafc;
#     margin-left: 0;
#     padding-left: 12px;
# }
# .data-distribution {
#     background: #f8fafc;
#     border: 2px solid #dbeafe;
#     border-radius: 10px;
#     padding: 20px;
#     margin: 20px 0;
# }
# .distribution-title {
#     color: #4338ca !important;
#     font-size: 1.4rem;
#     font-weight: 600;
#     margin-top: 0;
#     margin-bottom: 15px;
# }
# .distribution-list {
#     color: #1e3a8a;
#     font-size: 1.1rem;
#     font-weight: 500;
#     margin: 0;
# }
# .distribution-list li {
#     background-color: #f8fafc;
#     margin-bottom: 8px;
#     padding: 10px 15px;
#     border-radius: 6px;
#     border-left: 4px solid #60a5fa;
# }
# .conclusion-box {
#     background: #f8fafc;
#     border: 2px solid #dbeafe;
#     border-radius: 12px;
#     padding: 25px;
#     margin: 25px 0;
#     color: #1e3a8a;
#     font-size: 1.05rem;
#     line-height: 1.8;
#     font-style: italic;
# }
# .emphasis-text {
#     background-color: #f8fafc;
#     color: #black;
#     padding: 3px 8px;
#     border-radius: 4px;
#     font-weight: 600;
#     font-style: normal;
# }
# </style>
#
# <h2 class="results-header">Results Summary</h2>
#
# <div class="summary-intro">
# <p class="summary-text">This program counts the cell lines in ranges of damaging mutation sums and displays the results in the form of a histogram. The viewer can interactively filter the displayed data by tissue type, mutation value, and number of histogram bins. The program forms a flexible foundation for future analysis as filters can easily be added or modified.</p>
# </div>
